# %% [markdown]
# <a href="https://colab.research.google.com/github/datascience-vivek/Linear_Regression/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ROOT= '/content/drive/MyDrive/ML Class'

# %%
import os

# %%
os.chdir(ROOT)

# %%
# !ls
# Out:
# Advertising.csv  Linear_Regression.ipynb

# %%
assert ROOT == os.getcwd()

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/ML Class'

# %%
with open("test.txt", 'w') as f:
  f.writelines('hello world')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/ML Class/Advertising.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df['total_spend'] = df['TV']+ df['Radio']+ df['Newspaper']
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales  total_spend  \
# 0           1  230.1   37.8       69.2   22.1        337.1
# 1           2   44.5   39.3       45.1   10.4        128.9
# 2           3   17.2   45.9       69.3    9.3        132.4
# 3           4  151.5   41.3       58.5   18.5        251.3
# 4           5  180.8   10.8       58.4   12.9        250.0
#
#    337.09999999999997  128.9  132.39999999999998  251.3  ...  \
# 0               337.1  128.9               132.4  251.3  ...
# 1               337.1  128.9               132.4  251.3  ...
# 2               337.1  128.9               132.4  251.3  ...
# 3               337.1  128.9               132.4  251.3  ...
# 4               337.1  128.9               132.4  251.3  ...
#
#    86.39999999999999  92.3  52.9  212.4  191.29999999999998  55.7  107.2  \
# 0               86.4  92.3  52.9  212.4               191.3  55.7  107.2
# 1               86.4  92.3  52.9  212.4               191.3  55.7  107.2
# ...

# %%
sns.scatterplot(data= df, x= 'total_spend', y = 'Sales')

# %%
sns.regplot(data= df,x= 'total_spend',color='green', y = 'Sales' )

# %%
x = df['total_spend']
y= df['Sales']

# %%
np.polyfit(x,y, deg= 1)
# Out:
# array([0.04868788, 4.24302822])

# %%
potential_spend = np.linspace(0,500, 100)
potential_spend
# Out:
# array([  0.        ,   5.05050505,  10.1010101 ,  15.15151515,
#         20.2020202 ,  25.25252525,  30.3030303 ,  35.35353535,
#         40.4040404 ,  45.45454545,  50.50505051,  55.55555556,
#         60.60606061,  65.65656566,  70.70707071,  75.75757576,
#         80.80808081,  85.85858586,  90.90909091,  95.95959596,
#        101.01010101, 106.06060606, 111.11111111, 116.16161616,
#        121.21212121, 126.26262626, 131.31313131, 136.36363636,
#        141.41414141, 146.46464646, 151.51515152, 156.56565657,
#        161.61616162, 166.66666667, 171.71717172, 176.76767677,
#        181.81818182, 186.86868687, 191.91919192, 196.96969697,
#        202.02020202, 207.07070707, 212.12121212, 217.17171717,
#        222.22222222, 227.27272727, 232.32323232, 237.37373737,
#        242.42424242, 247.47474747, 252.52525253, 257.57575758,
#        262.62626263, 267.67676768, 272.72727273, 277.77777778,
#        282.82828283, 287.87878788, 292.92929293, 297.97979798,
# ...

# %%
## y = mx+c 
predicted_sales = 0.04868788*(potential_spend) + 4.24302822

# %%
sns.scatterplot(x= 'total_spend', y = 'Sales', data= df)
plt.plot(potential_spend, predicted_sales, color= 'green')

# %%
sns.pairplot(df)
